# %%
# !pip install nltk
# Out:
# ...
#    ---------------------------------------- 0.0/1.5 MB ? eta -:--:--
#    -------------------- ------------------- 0.8/1.5 MB 5.6 MB/s eta 0:00:01
#    ---------------------------------------- 1.5/1.5 MB 6.7 MB/s  0:00:00
# ...
#
#    ---------------------------------------- 0/2 [regex]
#    ---------------------------------------- 0/2 [regex]
#    -------------------- ------------------- 1/2 [nltk]
#    -------------------- ------------------- 1/2 [nltk]
#    -------------------- ------------------- 1/2 [nltk]
#    -------------------- ------------------- 1/2 [nltk]
#    -------------------- ------------------- 1/2 [nltk]
#    -------------------- ------------------- 1/2 [nltk]
#    -------------------- ------------------- 1/2 [nltk]
#    -------------------- ------------------- 1/2 [nltk]
#    -------------------- ------------------- 1/2 [nltk]
#    -------------------- ------------------- 1/2 [nltk]
#    -------------------- ------------------- 1/2 [nltk]
# ...

# %%
import nltk
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Welcome\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping tokenizers\punkt.zip.
# True

# %%
import sys
print(sys.executable)
# Out:
# c:\Users\Welcome\Desktop\python\venv1\python.exe

# %%
import nltk

nltk.download('punkt')
nltk.download('punkt_tab')   # IMPORTANT for newer NLTK
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Welcome\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     C:\Users\Welcome\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping tokenizers\punkt_tab.zip.
# True

# %%
import nltk
print(nltk.data.path)
# Out:
# ['C:\\Users\\Welcome/nltk_data', 'c:\\Users\\Welcome\\Desktop\\python\\venv1\\nltk_data', 'c:\\Users\\Welcome\\Desktop\\python\\venv1\\share\\nltk_data', 'c:\\Users\\Welcome\\Desktop\\python\\venv1\\lib\\nltk_data', 'C:\\Users\\Welcome\\AppData\\Roaming\\nltk_data', 'C:\\nltk_data', 'D:\\nltk_data', 'E:\\nltk_data']

# %%
import nltk

nltk.download('punkt', force=True)
nltk.download('punkt_tab', force=True)
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Welcome\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping tokenizers\punkt.zip.
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     C:\Users\Welcome\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping tokenizers\punkt_tab.zip.
# True

# %%
from nltk.tokenize import sent_tokenize

sent_tokenize("Hello world. This is Jagrat. NLP works now.")
# Out:
# ['Hello world.', 'This is Jagrat.', 'NLP works now.']

# %%
corpus="""Hello Welcome,to Jagrat Agrawal's NLP Tutorials.
Please go through the entire notebook! to become expert in NLP.
"""

# %%
print(corpus)
# Out:
# Hello Welcome,to Jagrat Agrawal's NLP Tutorials.
# Please go through the entire notebook! to become expert in NLP.

# %%
##  Tokenization
## Sentence-->paragraphs
from nltk.tokenize import sent_tokenize

# %%
documents=sent_tokenize(corpus)

# %%
type(documents)
# Out:
# list

# %%
for sentence in documents:
    print(sentence)
# Out:
# Hello Welcome,to Jagrat Agrawal's NLP Tutorials.
# Please go through the entire notebook!
# to become expert in NLP.

# %%
## Tokenization 
## Paragraph-->words
## sentence--->words
from nltk.tokenize import word_tokenize

# %%
word_tokenize(corpus)
# Out:
# ['Hello',
#  'Welcome',
#  ',',
#  'to',
#  'Jagrat',
#  'Agrawal',
#  "'s",
#  'NLP',
#  'Tutorials',
#  '.',
#  'Please',
#  'go',
#  'through',
#  'the',
#  'entire',
#  'notebook',
#  '!',
#  'to',
#  'become',
#  'expert',
#  'in',
#  'NLP',
#  '.']

# %%
for sentence in documents:
    print(word_tokenize(sentence))
# Out:
# ['Hello', 'Welcome', ',', 'to', 'Jagrat', 'Agrawal', "'s", 'NLP', 'Tutorials', '.']
# ['Please', 'go', 'through', 'the', 'entire', 'notebook', '!']
# ['to', 'become', 'expert', 'in', 'NLP', '.']

# %%
from nltk.tokenize import wordpunct_tokenize

# %%
wordpunct_tokenize(corpus)
# Out:
# ['Hello',
#  'Welcome',
#  ',',
#  'to',
#  'Jagrat',
#  'Agrawal',
#  "'",
#  's',
#  'NLP',
#  'Tutorials',
#  '.',
#  'Please',
#  'go',
#  'through',
#  'the',
#  'entire',
#  'notebook',
#  '!',
#  'to',
#  'become',
#  'expert',
#  'in',
#  'NLP',
#  '.']

# %%
from nltk.tokenize import TreebankWordTokenizer

# %%
tokenizer=TreebankWordTokenizer()

# %%
tokenizer.tokenize(corpus)
# Out:
# ['Hello',
#  'Welcome',
#  ',',
#  'to',
#  'Jagrat',
#  'Agrawal',
#  "'s",
#  'NLP',
#  'Tutorials.',
#  'Please',
#  'go',
#  'through',
#  'the',
#  'entire',
#  'notebook',
#  '!',
#  'to',
#  'become',
#  'expert',
#  'in',
#  'NLP',
#  '.']
